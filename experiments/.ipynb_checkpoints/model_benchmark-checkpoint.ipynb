# %% [markdown]
# ## Forecast Benchmarking

# %% [markdown]
# This notebook serves to recreate the EPAG RNN forecast for Inlets 1 and 2 at Kubel, before training and evaluating a series of auxiliary ML models designed to be used in the context of a stacked ensemble model.

# %% [markdown]
# #### Import

# %%
import pandas as pd
import numpy as np
import keras
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

from solutil import dbqueries as dbq
from solutil import evaluations as ev

# %% [markdown]
# #### Parameterization

# %%
# TS ID Assignment
act_inlet1 = 11127586
pred_inlet1 = 11055610

act_inlet2 = 11127590
pred_inlet2 = 11055614

# %%
# Parameter Assignment
date_from = datetime.strptime('01.03.2021', '%d.%m.%Y')
date_to = datetime.now() - timedelta(days=1)

# %%
# Load env variables
env_vars = dbq.get_env_variables(mandant='EPAG_ENERGIE')

# %% [markdown]
# #### TS Retrieval

# %%
# Inlet 1
df_act_inlet1 = dbq.get_timeseries_1h(act_inlet1, date_from, date_to, **env_vars)
df_pred_inlet1 = dbq.get_timeseries_1h(pred_inlet1, date_from, date_to, **env_vars)

# %%
# Inlet 2
df_act_inlet2 = dbq.get_timeseries_1h(act_inlet2, date_from, date_to, **env_vars)
df_pred_inlet2 = dbq.get_timeseries_1h(act_inlet1, date_from, date_to, **env_vars)

# %%
# Merge datasets
df_act_inlet1.name = 'act_inlet1'
df_inlets = df_act_inlet1.to_frame()
df_inlets['pred_inlet1'] = df_pred_inlet1
df_inlets['act_inlet2'] = df_act_inlet2
df_inlets['pred_inlet2'] = df_pred_inlet2

# %%
df_inlets
# Out:
#                            act_inlet1  pred_inlet1  act_inlet2  pred_inlet2
# Timestamp
# 2021-03-01 00:00:00+01:00    1.563610     1.807735    1.392077     1.563610
# 2021-03-01 01:00:00+01:00    1.572388     1.600004    1.392077     1.572388
# 2021-03-01 02:00:00+01:00    1.569493     1.433065    1.388438     1.569493
# 2021-03-01 03:00:00+01:00    1.560150     1.343673    1.378156     1.560150
# 2021-03-01 04:00:00+01:00    1.544482     1.315153    1.378861     1.544482
# ...                               ...          ...         ...          ...
# 2024-07-01 11:00:00+01:00    4.200000     3.766585    0.000000     4.200000
# 2024-07-01 12:00:00+01:00    4.200000     3.785422    0.000000     4.200000
# 2024-07-01 13:00:00+01:00    4.200000     3.800211    0.000000     4.200000
# 2024-07-01 14:00:00+01:00    4.200000     3.802565    0.000000     4.200000
# 2024-07-01 15:00:00+01:00    4.200000     3.787350    0.000000     4.200000
#
# [29248 rows x 4 columns]

# %% [markdown]
# #### Time Series Resampling

# %%
n_timestep = 6
df_inlets_4h = df_inlets.copy().resample(timedelta(hours=24 // n_timestep)).mean()

# %%
df_inlets_4h
# Out:
#                            act_inlet1  pred_inlet1  act_inlet2  pred_inlet2
# Timestamp
# 2021-03-01 00:00:00+01:00    1.566410     1.546119    1.387687     1.566410
# 2021-03-01 04:00:00+01:00    1.511735     1.314004    1.338084     1.511735
# 2021-03-01 08:00:00+01:00    1.407460     1.278593    1.268270     1.407460
# 2021-03-01 12:00:00+01:00    1.890060     1.505975    1.281545     1.890060
# 2021-03-01 16:00:00+01:00    1.951809     1.602436    1.497726     1.951809
# ...                               ...          ...         ...          ...
# 2024-06-30 20:00:00+01:00    4.200000     3.754528    0.000000     4.200000
# 2024-07-01 00:00:00+01:00    4.200000     3.795551    0.000000     4.200000
# 2024-07-01 04:00:00+01:00    4.200000     3.778045    0.000000     4.200000
# 2024-07-01 08:00:00+01:00    4.200000     3.755074    0.000000     4.200000
# 2024-07-01 12:00:00+01:00    4.200000     3.793887    0.000000     4.200000
#
# [7312 rows x 4 columns]

# %% [markdown]
# ### EPAG Model Evaluation 4h Frequency

# %%
df_inlets_trunc = df_inlets_4h[df_inlets_4h.index >= '2023-07-07 00:00:00+01:00'].copy()

# %%
# Actual vs. Prediction Plot
fig = ev.get_act_vs_pred_plot(df_inlets_trunc['act_inlet1'], df_inlets_trunc['pred_inlet1'])

# %%
# Get Evaluation Metrics for Inlet 1 
inlet1_metrics = ev.get_eval_metrics(df_inlets_trunc['act_inlet1'], df_inlets_trunc['pred_inlet1'])
inlet1_metrics
# Out:
# {'mae': 0.4828125658504343,
#  'mse': 0.5097888791692079,
#  'rmse': 0.7139950134064018,
#  'mape': 193739166788790.72,
#  'non-na%': 1.0,
#  'n_actual_obs': 2164,
#  'n_pred_nas': 0}

# %%
# Get Evaluation Metrics for Inlet 2
inlet2_metrics = ev.get_eval_metrics(df_inlets_trunc['act_inlet2'], df_inlets_trunc['pred_inlet2'])
inlet2_metrics
# Out:
# {'mae': 0.6354597186585451,
#  'mse': 0.9505723486412612,
#  'rmse': 0.9749729989293351,
#  'mape': 201777821694990.28,
#  'non-na%': 1.0,
#  'n_actual_obs': 2164,
#  'n_pred_nas': 0}

# %%
# Save data as csv
df_inlets_4h.to_csv('stacking_data/ypred_benchmark_4h.csv')

# %% [markdown]
# ### EPAG Model Evaluation 1h Frequency

# %%
df_inlets_trunc = df_inlets[df_inlets.index >= '2023-07-07 00:00:00+01:00'].copy()

# %%
# Actual vs. Prediction Plot
fig = ev.get_act_vs_pred_plot(df_inlets_trunc['act_inlet1'], df_inlets_trunc['pred_inlet1'])

# %%
# Get Evaluation Metrics for Inlet 1 
inlet1_metrics = ev.get_eval_metrics(df_inlets_trunc['act_inlet1'], df_inlets_trunc['pred_inlet1'])
inlet1_metrics
# Out:
# {'mae': 0.498036823076005,
#  'mse': 0.5515349735518394,
#  'rmse': 0.7426540066220874,
#  'mape': 208025921117711.5,
#  'non-na%': 1.0,
#  'n_actual_obs': 8656,
#  'n_pred_nas': 0}

# %%
# Get Evaluation Metrics for Inlet 2
inlet2_metrics = ev.get_eval_metrics(df_inlets_trunc['act_inlet2'], df_inlets_trunc['pred_inlet2'])
inlet2_metrics
# Out:
# {'mae': 0.648757281858197,
#  'mse': 1.0140171857256128,
#  'rmse': 1.0069842033148348,
#  'mape': 255014629209572.16,
#  'non-na%': 1.0,
#  'n_actual_obs': 8656,
#  'n_pred_nas': 0}

# %%
# Save data as csv
df_inlets.to_csv('stacking_data/ypred_benchmark_1h.csv')
